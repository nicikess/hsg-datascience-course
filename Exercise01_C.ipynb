# %% [markdown]
# # Exercise 1: Part C
#
# This exercise relates to the *Boston* data set which can be found in `../datasets/Boston.csv` file as a _csv_ file.

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## Task 1: Load and investigate data
# Load the csv file `../datasets/Boston.csv` into a DataFrame. Call this variable `boston`.
#
# Look at the DataFrame and understand the data. How many rows? How many columns? What to the columns represent? (There is enough [literature](https://duckduckgo.com/?q=boston+dataset) about this specific dataset.)

# %%
# YOUR CODE HERE
df = pd.read_csv("../data/Boston.csv")
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %% [markdown]
# ## Task 2: Load and investigate data
# The target that we plan to predict with this dataset is the column `medv` ("Median value of owner-occupied homes in \$1000's").
#
# Use your knowledge from A and B to check if there is some relationshop between any of the columns and this target.

# %%
# YOUR CODE HERE
sns.pairplot(
    df,
    y_vars=["medv"]
)
plt.show()

# %% [markdown]
# ## Task 3: Binning
# Sometimes, we don't care about the actual value that a regression model might return but only if the prediction is _high_, _low_, or _middle_. For this, we need _binning_.
#
# Look for a possibility to put the target data into these three bins, and store the result in a new column: `medv_bins`.
#
# Then, use the same function to plot the same plot as above but with the new bins. Does it make it easier to find a relationship?

# %%
pd.qcut(
    df["medv"],
    q=3
)
# Out:
# 0         (23.7, 50.0]
# 1       (18.833, 23.7]
# 2         (23.7, 50.0]
# 3         (23.7, 50.0]
# 4         (23.7, 50.0]
#             ...
# 501     (18.833, 23.7]
# 502     (18.833, 23.7]
# 503       (23.7, 50.0]
# 504     (18.833, 23.7]
# 505    (4.999, 18.833]
# Name: medv, Length: 506, dtype: category
# Categories (3, interval[float64, right]): [(4.999, 18.833] < (18.833, 23.7] < (23.7, 50.0]]

# %% [markdown]
# # Exercise 1: Part B
#
# This exercise relates to the *Auto* data set which can be found in `../datasets/College.csv` file as a _csv_ file.

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## Task 1: Load and Clean data
# Load the csv file `../datasets/Auto.csv` into a DataFrame. Call this variable `auto`.
#
# Remove _invalid_ values from the `horsepower` column (Hint: look at the type.)

# %%
# YOUR CODE HERE
df = pd.read_csv("../data/Auto.csv")
df['horsepower'] = pd.to_numeric(df['horsepower'],errors='coerce')
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %% [markdown]
# ## Task 2: Qualitative/Quantitative
#
# ### Task 2.1:
# Look at the data in `auto` and identify which predictors/columns/variables are *qualitative* or *quantiative*.
# Store the column names in two lists: `qualitative` and `quantitative`.

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ### Task 2.2: range, std, and mean.
#
# What is the _range_ (_min_ and _max_), standard deviation and mean of the quantitative predictors?
#
# Use _f_-strings to format the values and round each entry to 2 decimal places.
#
# _Hint: Use a loop over the quantitative list and print the information line-wise._

# %%
qualitative = ["name", "origin","year"]
quantitative = ["cylinders","displacement","horsepower","weight","acceleration"]
df["horsepower"] = pd.to_numeric(df["horsepower"], errors="coerce")
df["horsepower"]
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 392     86.0
# 393     52.0
# 394     84.0
# 395     79.0
# 396     82.0
# Name: horsepower, Length: 397, dtype: float64

# %%
for q in quantitative:
    print(df[q].min(), df[q].max(), df[q].std() ,df[q].mean())
# Out:
# 3 8 1.7015769807918517 5.458438287153652
# 68.0 455.0 104.37958329992945 193.53274559193954
# 46.0 230.0 38.49115993282855 104.46938775510205
# 1613 5140 847.9041194897246 2970.2619647355164
# 8.0 24.8 2.7499952929761515 15.555667506297214

# %% [markdown]
# ### Task 2.3: Remove rows
#
# Now, remove the 10th through 85th obversation.
# What are the range, standard deviation, and mean now?
#
# Print them again similar to above.
#
# **Do not modify the `auto` DataFrame inplace!**

# %%
df.iloc[10:86]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 10  15.0          8         383.0       170.0    3563          10.0    70
# 11  14.0          8         340.0       160.0    3609           8.0    70
# 12  15.0          8         400.0       150.0    3761           9.5    70
# 13  14.0          8         455.0       225.0    3086          10.0    70
# 14  24.0          4         113.0        95.0    2372          15.0    70
# ..   ...        ...           ...         ...     ...           ...   ...
# 81  28.0          4          97.0        92.0    2288          17.0    72
# 82  23.0          4         120.0        97.0    2506          14.5    72
# 83  28.0          4          98.0        80.0    2164          15.0    72
# 84  27.0          4          97.0        88.0    2100          16.5    72
# 85  13.0          8         350.0       175.0    4100          13.0    73
#
#     origin                         name
# ...

# %% [markdown]
# ### Task 2.4: Plotting
# Using the full `auto` dataset again, we want to predict the mileage per gallon (`mpg`).
#
# Check visually which predictors have a strong relationship for predicting `mpg`.
#
# Store the names of these columns in the list: `predictors`.
#
# _Hint: You already used this function in Exercise 01_A._

# %%
# YOUR CODE HERE
sns.pairplot(
    df,
    y_vars=["mpg"]
)
plt.show()

# %% [markdown]
# # Exercise 2: Part G
#
# In this exercise we will focus on correlation.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
import statsmodels.formula.api as smf

# %%
def task7_data(seed=42):
    np.random.seed(seed)
    df = pd.DataFrame()
    df["X1"] = np.random.uniform(low=0.0, high=1.0, size=100)
    df["X2"] = 0.5 * df["X1"] + np.random.normal(0, 1, 100) / 10
    df["y"] = 2 + 2 * df["X1"] + 0.3 * df["X2"] + np.random.normal(0, 1, 100)
    return df

data = task7_data()
data
# Out:
#           X1        X2         y
# 0   0.374540  0.195975  2.820875
# 1   0.950714  0.445456  5.488600
# 2   0.731994  0.375173  3.311883
# 3   0.598658  0.100572  5.947658
# 4   0.156019  0.056042  2.954517
# ..       ...       ...       ...
# 95  0.493796  0.165317  1.601324
# 96  0.522733  0.253656  4.284726
# 97  0.427541  0.247886  2.939681
# 98  0.025419  0.040379  1.081443
# 99  0.107891  0.136664  2.718886
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Task G1: Correlation
#
# Plot the correlation between $X_1$ and $X_2$ as a scatterplot.

# %%
corr = data.corr()
plt.scatter(data["X1"],data["X2"])
